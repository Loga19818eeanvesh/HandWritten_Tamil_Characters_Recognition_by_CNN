02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/109t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/089t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/076t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/147t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/139t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/097t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/153t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/112t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/143t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/013t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/144t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/102t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/155t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/082t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/143t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/090t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/086t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/105t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/060t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/154t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/101t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/084t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/087t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/120t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/141t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/024t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/056t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/131t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/149t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/076t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/050t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/116t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/053t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/047t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/041t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/114t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/103t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/096t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/021t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/017t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/025t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/091t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/079t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/062t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/155t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/132t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/093t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/071t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/118t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/080t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/010t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/097t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/100t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/067t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/104t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/047t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/051t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/033t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/151t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/140t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/044t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/128t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/064t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/000t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/068t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/002t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/075t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/015t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/009t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/007t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/008t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/095t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/119t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/038t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/085t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/077t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/014t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/028t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/008t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/105t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/137t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/005t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/063t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/116t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/085t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/048t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/056t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/034t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/107t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/069t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/009t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/137t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/036t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/111t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/084t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/153t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/145t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/005t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/028t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/014t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/062t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/079t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/035t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/130t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/023t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/094t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/082t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/122t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/142t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/052t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/134t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/117t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/139t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/011t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/003t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/054t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/036t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/087t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/019t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/091t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/059t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/125t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/083t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/092t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/088t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/049t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/068t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/138t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/122t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/016t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/138t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/154t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/126t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/118t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/002t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/035t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/066t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/144t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/064t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/083t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/134t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/132t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/019t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/106t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/039t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/126t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/117t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/023t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/015t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/135t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/043t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/038t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/006t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/042t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/016t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/058t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/098t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/099t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/099t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/011t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/073t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/043t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/041t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/027t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/040t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/110t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/032t02.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/042t01.tiff
# ./hpl-tamil-iwfhr06-train-offline/usr_177/136t01.tiff

# %% [markdown]
# Data Preprocessing. Making 156 folders each for each of 156 Tamil characters and copying characters into its respective folder.
# The Folder name of a character is same as its class Id given for each character as shown in above table.

# %%
import os
import shutil

#making a directory /tmp/processedData/
train_target = "/tmp/processedData/"
os.mkdir(os.path.join("/tmp/", "processedData"))

data_dir = "/root/hpl-tamil-iwfhr06-train-offline"

#making 156 subdirectories in /tmp/processedData/ for each character
for i in range(156):
    os.mkdir(os.path.join(train_target, str(i)))

data_count = 0 #to count noof total images in data

#traverse original untar source directory and copy each character file to the subdirectory in /tmp/processedData/ with name same as character class
#Refer python documentation to know how os.walk() works
for root, dirs, files in os.walk(data_dir):
  #print(root)
  #print(dirs)
  #print(files)
  #print("_______________")
  for dir in dirs:
    for dir_root, subdirs, dir_files in os.walk(os.path.join(root, dir)):
      #print(root)
      #print(dirs)
      #print(files)
      #print("_______________")
      for file_name in dir_files:
        file_path = os.path.join(dir_root, file_name)
        char = file_name[:3]
        if char == "Thu":
          continue
        new_name = char + 'L' + dir[4:] + file_name[3:]
        #print(char)
        location = os.path.join(train_target, str(int(char)), new_name)
        shutil.copy(file_path, location)
        data_count += 1

print(data_count)
# Out:
# 50683

# %% [markdown]
# Now as we have copied all 156 tamil characters images to their respective subfolders in /tmp/processedData/ with name same as classId of character Its time to split data into TrainingSet and TestSet

# %%
training_dir = "/tmp/processedData/training/" 
testing_dir = "/tmp/processedData/testing/"

#make training and testing dirctories as /tmp/processedData/training/ and /tmp/processedData/testing/ respectively
try:

  os.mkdir('/tmp/processedData/training')
  os.mkdir('/tmp/processedData/testing')

  #In training and testing dirctories make subdirctories for each of 156 characters with subfolder names same as charaterter classIds
  for i in range(156):
    os.mkdir(os.path.join(training_dir , str(i)))
    os.mkdir(os.path.join(testing_dir , str(i)))

except OSError:
    pass

# %%
#Function takes SOURCE directory of a character and copies some images of character to TRAINING directory and remaining to TESTING directory as specified by Split_Size

def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):

  files = []

  #Append all filenames in Source directory to files
  for filename in os.listdir(SOURCE):
    file = SOURCE + filename
    if os.path.getsize(file) > 0:
      files.append(filename)
    else:
      print(filename + " is zero length, so ignoring.")

  #Calculating training_size and testing_size
  training_length = int(len(files) * SPLIT_SIZE)
  testing_length = int(len(files) - training_length)

  #shuffle filenames in files list
  shuffled_set = random.sample(files, len(files))


  training_set = shuffled_set[0:training_length]
  testing_set = shuffled_set[-testing_length:]

  #Copying filenames in training_set to TRAINING Directory
  for filename in training_set:
    this_file = SOURCE + filename
    destination = TRAINING + filename
    copyfile(this_file, destination)
  
  #Copying filenames in testing_set to TESTING Directory
  for filename in testing_set:
    this_file = SOURCE + filename
    destination = TESTING + filename
    copyfile(this_file, destination)

# %%
#By using above function spliting Data to Training and Testing Sets

split_size = 0.9

source_dir ="/tmp/processedData/"
training_dir = "/tmp/processedData/training/"
testing_dir = "/tmp/processedData/testing/"

for i in range(156):

  source_directory = source_dir + str(i) + "/"
  training_directory = training_dir + str(i) + "/"
  testing_directory = testing_dir + str(i) + "/"
  split_data(source_directory, training_directory, testing_directory, split_size)

# %% [markdown]
# Visualise some images from dataset

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#funtion to plot the images in "dir->training or testing" directory char specify which subdirectory and no_of_pics tell how many of them to show
def show_character_image(char,dir,no_of_pics):
  
  next_char = [dir+str(char)+"/"+fname for fname in os.listdir(dir+str(char)+"/")[0:no_of_pics]]
  
  for i, img_path in enumerate(next_char):
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.axis('Off')
    plt.show()

# %%
show_character_image(0,training_dir,10)

# %%
show_character_image(1,training_dir,2)

# %%
show_character_image(2,training_dir,2)

# %%
show_character_image(3,training_dir,2)

# %%
#normalize input which are in range [0,255] to [0,1] by using keras.preprocessing.image.ImageDataGenerator class using the rescale parameter 
train_datagen = ImageDataGenerator(rescale=1./255)

#The ImageDataGenerator class allows you to instantiate generators of augmented image batches (and their labels) via .flow(data, labels) or .flow_from_directory(directory).
#Keep target_size=(128, 128) to resize all images to same size of(128,128)
#Keep class_mode='categorical' since we need multiclass labels
train_generator = train_datagen.flow_from_directory(training_dir,
                                                    batch_size=64,
                                                    class_mode='categorical',
                                                    target_size=(128, 128))

validation_datagen = ImageDataGenerator(rescale = 1./255)

validation_generator = validation_datagen.flow_from_directory(
	testing_dir,
	target_size=(128,128),
	class_mode='categorical',
  batch_size=64
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py:179: UserWarning: Using ".tiff" files with multiple bands will cause distortion. Please verify your output.
#   warnings.warn('Using ".tiff" files with multiple bands '
# Found 45544 images belonging to 156 classes.
# Found 5139 images belonging to 156 classes.

# %% [markdown]
# We Will use transfer learning on InceptionV3 network as our model. Its good to use transfer laerning on well trained networks to get good results. Inception v3 is a widely-used image recognition model that has been shown to attain greater than 78.1% accuracy on the ImageNet dataset. Since InceptionV3 is also trained for classification problem on millions of images it must have learned important features of image we will freeze the convolution layers to take advantage of the features it has learned already. we will add some dense layers at end which we will train for this specific task of tamil character recognition.

# %%
# Download the pre-trained weights. No top means it excludes the fully connected layer it uses for classification.
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5 \
    -O /tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# --2022-02-17 08:57:30--  https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.11.128, 74.125.31.128, 173.194.210.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.11.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87910968 (84M) [application/x-hdf]
# Saving to: ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’
#
# /tmp/inception_v3_w 100%[===================>]  83.84M   190MB/s    in 0.4s
#
# 2022-02-17 08:57:30 (190 MB/s) - ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’ saved [87910968/87910968]

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import layers

# %%
# Set the weights file you downloaded into a variable
local_weights_file = '/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
# Initialize the base model.
# Set the input shape and remove the dense layers.
pre_trained_model = InceptionV3(input_shape = (128, 128, 3), 
                                include_top = False, 
                                weights = None)

# %%
# Load the pre-trained weights you downloaded.
pre_trained_model.load_weights(local_weights_file)

# Freeze the weights of the layers.
for layer in pre_trained_model.layers:
  layer.trainable = False

# %%
pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 63, 63, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 63, 63, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 63, 63, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 61, 61, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 61, 61, 64)   18432       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 61, 61, 64)  192         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 64)  0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 30, 30, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 30, 30, 80)  240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 30, 30, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 28, 28, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 28, 28, 192)  576        ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 28, 28, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 192)  0          ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (None, 13, 13, 64)  192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 13, 13, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 13, 13, 48)  144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 13, 13, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 13, 13, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (None, 13, 13, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 13, 13, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 13, 13, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 13, 13, 64)  192         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 13, 13, 96)  288         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 13, 13, 32)  96          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 13, 13, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 13, 13, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 13, 13, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (None, 13, 13, 48)  144         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 13, 13, 96)  288         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 13, 13, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_106 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 13, 13, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 13, 13, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 13, 13, 64)  192         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 13, 13, 96)  288         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 13, 13, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 13, 13, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 13, 13, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 13, 13, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 13, 13, 48)  144         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 13, 13, 96)  288         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 13, 13, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_113 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 13, 13, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 13, 13, 64)  192         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 13, 13, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 13, 13, 96)  288         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 13, 13, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 13, 13, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 13, 13, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 13, 13, 96)  288         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 6, 6, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 6, 6, 96)     82944       ['activation_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 6, 6, 384)   1152        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 6, 6, 96)    288         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_120[0][0]']
#
#  activation_123 (Activation)    (None, 6, 6, 96)     0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 6, 6, 768)    0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 6, 6, 128)   384         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 6, 6, 128)   384         ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_129[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 6, 6, 128)   384         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 6, 6, 128)   384         ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_125[0][0]']
#
#  activation_130 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_130[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 6, 6, 128)   384         ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 6, 6, 128)   384         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_126[0][0]']
#
#  activation_131 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 6, 6, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_124 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 6, 6, 192)   576         ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 6, 6, 192)   576         ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 6, 6, 192)   576         ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 6, 6, 192)   576         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_124[0][0]']
#
#  activation_127 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_127[0][0]']
#
#  activation_132 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 6, 6, 768)    0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 6, 6, 160)   480         ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 6, 6, 160)   480         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_139[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_139[0][0]']
#
#  batch_normalization_135 (Batch  (None, 6, 6, 160)   480         ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 6, 6, 160)   480         ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 6, 6, 160)   480         ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 6, 6, 160)   480         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 6, 6, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_134 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 6, 6, 192)   576         ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 6, 6, 192)   576         ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 6, 6, 192)   576         ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 6, 6, 192)   576         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 6, 6, 768)    0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 6, 6, 160)   480         ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 6, 6, 160)   480         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (None, 6, 6, 160)   480         ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 6, 6, 160)   480         ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_145[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (None, 6, 6, 160)   480         ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 6, 6, 160)   480         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 6, 6, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_144 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_146[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_151[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 6, 6, 192)   576         ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 6, 6, 192)   576         ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 6, 6, 192)   576         ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 6, 6, 192)   576         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_147[0][0]']
#
#  activation_152 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_152[0][0]']
#
#  activation_153 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_153[0][0]']
#
#  mixed6 (Concatenate)           (None, 6, 6, 768)    0           ['activation_144[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_152[0][0]',
#                                                                   'activation_153[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 2, 2, 1280)   0           ['activation_165[0][0]',
#                                                                   'activation_169[0][0]',
#                                                                   'max_pooling2d_7[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 2, 2, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_174 (Batch  (None, 2, 2, 448)   1344        ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_174 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 2, 2, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_171 (Batch  (None, 2, 2, 384)   1152        ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 2, 2, 384)   1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_171[0][0]']
#
#  activation_175 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 2, 2, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_170 (Conv2D)            (None, 2, 2, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (None, 2, 2, 384)   1152        ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 2, 2, 384)   1152        ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 2, 2, 384)   1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 2, 2, 384)   1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  conv2d_178 (Conv2D)            (None, 2, 2, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 2, 2, 320)   960         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_172[0][0]']
#
#  activation_173 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_173[0][0]']
#
#  activation_176 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_177 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 2, 2, 192)   576         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 2, 2, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 2, 2, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (None, 2, 2, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 2, 2, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (None, 2, 2, 448)   1344        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 2, 2, 448)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 2, 2, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 2, 2, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_180 (Batch  (None, 2, 2, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 2, 2, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_184 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 2, 2, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 2, 2, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_179 (Conv2D)            (None, 2, 2, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (None, 2, 2, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 2, 2, 384)   1152        ['conv2d_182[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 2, 2, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 2, 2, 384)   1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  conv2d_187 (Conv2D)            (None, 2, 2, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (None, 2, 2, 320)   960         ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_182[0][0]']
#
#  activation_185 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (None, 2, 2, 384)    0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 2, 2, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 2, 2, 320)    0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 2, 2, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 2, 2, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (None, 2, 2, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import Model

# %%
# Choose `mixed_7` as the last layer of your base model
last_layer = pre_trained_model.get_layer('mixed7')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_output)
# Add a fully connected layer with 1,024 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.2
x = layers.Dropout(0.2)(x)                  
# Add a final sigmoid layer for classification
x = layers.Dense  (156, activation='softmax')(x)           

# Append the dense network to the base model
model = Model(pre_trained_model.input, x) 

# Print the model summary. See your dense network connected at the end.
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 63, 63, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 63, 63, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 63, 63, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 61, 61, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 61, 61, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 61, 61, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 61, 61, 64)   18432       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 61, 61, 64)  192         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 61, 61, 64)   0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 64)  0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 30, 30, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 30, 30, 80)  240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 30, 30, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 28, 28, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 28, 28, 192)  576        ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 28, 28, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 192)  0          ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (None, 13, 13, 64)  192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 13, 13, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 13, 13, 48)  144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 13, 13, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 13, 13, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (None, 13, 13, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 13, 13, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 13, 13, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 13, 13, 64)  192         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 13, 13, 96)  288         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 13, 13, 32)  96          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 13, 13, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 13, 13, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 13, 13, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (None, 13, 13, 48)  144         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 13, 13, 96)  288         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 13, 13, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_106 (Conv2D)            (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 13, 13, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 13, 13, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 13, 13, 64)  192         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 13, 13, 96)  288         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 13, 13, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 13, 13, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 13, 13, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 13, 13, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 13, 13, 48)  144         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 13, 13, 96)  288         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 13, 13, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_113 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 13, 13, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 13, 13, 64)  192         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 13, 13, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 13, 13, 96)  288         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 13, 13, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 13, 13, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 13, 13, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 13, 13, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 13, 13, 96)  288         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 6, 6, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 6, 6, 96)     82944       ['activation_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 6, 6, 384)   1152        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 6, 6, 96)    288         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_120[0][0]']
#
#  activation_123 (Activation)    (None, 6, 6, 96)     0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 6, 6, 768)    0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 6, 6, 128)   384         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 6, 6, 128)   384         ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_129[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 6, 6, 128)   384         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 6, 6, 128)   384         ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_125[0][0]']
#
#  activation_130 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_130[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 6, 6, 128)    114688      ['activation_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 6, 6, 128)   384         ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 6, 6, 128)   384         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_126[0][0]']
#
#  activation_131 (Activation)    (None, 6, 6, 128)    0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 6, 6, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_124 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 6, 6, 192)    172032      ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 6, 6, 192)   576         ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 6, 6, 192)   576         ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 6, 6, 192)   576         ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 6, 6, 192)   576         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_124[0][0]']
#
#  activation_127 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_127[0][0]']
#
#  activation_132 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 6, 6, 768)    0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 6, 6, 160)   480         ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 6, 6, 160)   480         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_139[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_139[0][0]']
#
#  batch_normalization_135 (Batch  (None, 6, 6, 160)   480         ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 6, 6, 160)   480         ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 6, 6, 160)   480         ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 6, 6, 160)   480         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 6, 6, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_134 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 6, 6, 192)   576         ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 6, 6, 192)   576         ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 6, 6, 192)   576         ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 6, 6, 192)   576         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 6, 6, 768)    0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 6, 6, 160)   480         ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 6, 6, 160)   480         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (None, 6, 6, 160)   480         ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 6, 6, 160)   480         ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_145[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 6, 6, 160)    179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (None, 6, 6, 160)   480         ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 6, 6, 160)   480         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (None, 6, 6, 160)    0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 6, 6, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_144 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_146[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 6, 6, 192)    215040      ['activation_151[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 6, 6, 192)   576         ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 6, 6, 192)   576         ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 6, 6, 192)   576         ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 6, 6, 192)   576         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_147[0][0]']
#
#  activation_152 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_152[0][0]']
#
#  activation_153 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_153[0][0]']
#
#  mixed6 (Concatenate)           (None, 6, 6, 768)    0           ['activation_144[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_152[0][0]',
#                                                                   'activation_153[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  batch_normalization_158 (Batch  (None, 6, 6, 192)   576         ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_158[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 6, 6, 192)   576         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_159[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_159[0][0]']
#
#  batch_normalization_155 (Batch  (None, 6, 6, 192)   576         ['conv2d_155[0][0]']
#  Normalization)
#
#  batch_normalization_160 (Batch  (None, 6, 6, 192)   576         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_155[0][0]']
#
#  activation_160 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_160[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_155[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_160[0][0]']
#
#  batch_normalization_156 (Batch  (None, 6, 6, 192)   576         ['conv2d_156[0][0]']
#  Normalization)
#
#  batch_normalization_161 (Batch  (None, 6, 6, 192)   576         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_156[0][0]']
#
#  activation_161 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_161[0][0]']
#
#  average_pooling2d_15 (AverageP  (None, 6, 6, 768)   0           ['mixed6[0][0]']
#  ooling2D)
#
#  conv2d_154 (Conv2D)            (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_156[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 6, 6, 192)    258048      ['activation_161[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 6, 6, 192)    147456      ['average_pooling2d_15[0][0]']
#
#  batch_normalization_154 (Batch  (None, 6, 6, 192)   576         ['conv2d_154[0][0]']
#  Normalization)
#
#  batch_normalization_157 (Batch  (None, 6, 6, 192)   576         ['conv2d_157[0][0]']
#  Normalization)
#
#  batch_normalization_162 (Batch  (None, 6, 6, 192)   576         ['conv2d_162[0][0]']
#  Normalization)
#
#  batch_normalization_163 (Batch  (None, 6, 6, 192)   576         ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_154[0][0]']
#
#  activation_157 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_157[0][0]']
#
#  activation_162 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_162[0][0]']
#
#  activation_163 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_163[0][0]']
#
#  mixed7 (Concatenate)           (None, 6, 6, 768)    0           ['activation_154[0][0]',
#                                                                   'activation_157[0][0]',
#                                                                   'activation_162[0][0]',
#                                                                   'activation_163[0][0]']
#
#  flatten (Flatten)              (None, 27648)        0           ['mixed7[0][0]']
#
#  dense (Dense)                  (None, 512)          14156288    ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 156)          80028       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 23,211,580
# Trainable params: 14,236,316
# Non-trainable params: 8,975,264
# __________________________________________________________________________________________________

# %%
# Set the training parameters
model.compile(optimizer = RMSprop(learning_rate=0.001), 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
# Train the model.
class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs={}):
            if logs.get('accuracy') is not None and logs.get('accuracy') > 0.99:
                print("\nReached 99% accuracy so cancelling training!")
                self.model.stop_training = True
callbacks = myCallback()

history = model.fit(
            train_generator,
            validation_data = validation_generator,
            steps_per_epoch = 712,
            epochs = 10,
            validation_steps = 81,
            verbose = 2,
            callbacks=[callbacks])
# Out:
# Epoch 1/10
# 712/712 - 1368s - loss: 1.2854 - accuracy: 0.6659 - val_loss: 0.5297 - val_accuracy: 0.8408 - 1368s/epoch - 2s/step
# Epoch 2/10
# 712/712 - 1373s - loss: 0.4703 - accuracy: 0.8552 - val_loss: 0.5103 - val_accuracy: 0.8589 - 1373s/epoch - 2s/step
# Epoch 3/10
# 712/712 - 1370s - loss: 0.3374 - accuracy: 0.8963 - val_loss: 0.5056 - val_accuracy: 0.8644 - 1370s/epoch - 2s/step
# Epoch 4/10
# 712/712 - 1419s - loss: 0.2740 - accuracy: 0.9180 - val_loss: 0.4879 - val_accuracy: 0.8815 - 1419s/epoch - 2s/step
# Epoch 5/10
# 712/712 - 1396s - loss: 0.2259 - accuracy: 0.9317 - val_loss: 0.5492 - val_accuracy: 0.8854 - 1396s/epoch - 2s/step
# Epoch 6/10
# 712/712 - 1374s - loss: 0.1961 - accuracy: 0.9419 - val_loss: 0.5680 - val_accuracy: 0.8922 - 1374s/epoch - 2s/step
# Epoch 7/10
# 712/712 - 1365s - loss: 0.1763 - accuracy: 0.9488 - val_loss: 0.6578 - val_accuracy: 0.8850 - 1365s/epoch - 2s/step
# Epoch 8/10
# 712/712 - 1356s - loss: 0.1631 - accuracy: 0.9535 - val_loss: 0.6310 - val_accuracy: 0.8980 - 1356s/epoch - 2s/step
# Epoch 9/10
# 712/712 - 1353s - loss: 0.1486 - accuracy: 0.9587 - val_loss: 0.6837 - val_accuracy: 0.8904 - 1353s/epoch - 2s/step
# Epoch 10/10
# 712/712 - 1357s - loss: 0.1357 - accuracy: 0.9621 - val_loss: 0.7123 - val_accuracy: 0.8988 - 1357s/epoch - 2s/step

# %%
model.save('my_model.h5')

# %%
import matplotlib.pyplot as plt

#plot graphs of accuracy and loss
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# Obtained Validation_Accuracy = 89.9%

# %% [markdown]
# Its not that high accuracy because of following reasons
#
# 1.   Isolated Tamil character recognition is a much harder problem because of  the larger category set of 156 classes and potential confusion due to similarity between handwritten characters.
# 2.   Unlike English many of the tamil characters will be similar which is the case in most Indian Languages like telugu,sanskrit,hindi.
# 3.   I dont have access to high computational power, so have trained for only 10 epochs and also tried only few models and few range for hyperparameters.

# %% [markdown]
# May be one can improve accuracy further by fine tuning learning_rate and drop_out_rate, number_of_neurons in final dense layer before softmax layer and also by using different optimizing algorithm like adam, sgd

# %%
#The dictionary containing the mapping from class names(i.e name of subdirrectory which contain char) to class indices(i.e label of that char) can be obtained via train_generator.class_indices
print(train_generator.class_indices)

#make a new dictionary containing the mapping from class indices(labels) to class names(name of char sub-dir)
class_name_to_labels = train_generator.class_indices
labels_to_class_name = {}
for name in class_name_to_labels:
  labels_to_class_name[class_name_to_labels[name]] = name

print(labels_to_class_name)

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(128, 128))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(fn)
  label = np.argmax(classes[0])
  class_name = labels_to_class_name[label]
  print(class_name)
# Out:
#      <input type="file" id="files-879ffdcc-1b97-4c05-8f11-251c48f7f9a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-879ffdcc-1b97-4c05-8f11-251c48f7f9a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
